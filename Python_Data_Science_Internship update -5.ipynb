# %%
#DATA SCIENCE SESSION 01 - 2ND FEB

print ("welcome to the class Rachana!")
print("2+2")

Num1 = 89
Num2 = 1
print(Num1 + Num2)
print(Num1 * Num2)
print(Num1 / Num2)
print(Num1 // Num2) #non decimal
print(Num1 % Num2)  #reminder


#String datatype
fName = "Ria"
lName = "Maro"
print(fName + lName)

#float datatypes
Num1 = 89.90
Num2 = 1.89
print(Num1 + Num2)

#inputs
Num1 = int(input("enter number 1:"))
Num2 = int(input("enter number 2 :"))

#booleans - True or False
#relstional operators
a = 8
b = 9
print(a + b)
print(a * b)
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b) # compare
print(a!=b) #Not equal

#control structure
if a > b: #indentation
  print("a is greater than b")
else:
  print("b is greater")

  #greatest among three numbers using nested if else
  a = 90
  b = 89
  c = 67

  if a>b:
    if a>c:
      print("a is greater")
    else:
     print("c is greater")
  else:
      if b>c:
      print("b is greater")
 else:
      print("c is greater")



#find wheather a  number is even or odd
if a % 2 == 0:
  print("even")
else:
  print("odd")


#wheather a number is positive or negative or zero
  if a == 0:
    print("zero")
  else:
    if a > 0:
      print("a is positive")
    else:
      print("negative")

#wheather a number i sprime or not
#palindrome and amstring problems

# %%
#DATA SCIENCE SESSION 02 - 4TH FEB

a = 5
b = 8
c = 7
if a > b and a > c:
  print("a is greater")
elif b > c:
  print("b is greater")
else:
  print("c is greater")


  #rock paper scissors
  import random
  print("welcome to the game")
  while True:
    user = input("type rock paper scissors")
    print ("you chose : ", user)
    computer = random.randint(1,3)
    if computer == 1:
      computer = 'rock'
    elif computer == 2:
      computer = 'paper'
    else:
      computer = 'scissors'
    print("computer chose : ", computer)
    if computer == user:
      print("draw")
    elif (user == 'rock' and computer == 'scissors') or (user == 'paper' and computer == 'rock') or (user == 'scissors' and computer == 'paper'):
      print("you win")
    else:
      print("computer wins")



name = "Rachana"
print(name[3:7])




#CODINGBAT PROBLEMS

# String-1 > hello_name
def hello_name(name):
  return "Hello " + name + "!"


# String-1 > make_abba
def make_abba(a, b):
  return a + b +b + a

# String-1 > make_tags
def make_tags(tag, word):
  return "<" + tag + ">"  + word + "</" + tag +">"

# String-1 > make_out_word
def make_out_word(out, word):
  return out [0:2] + word + out[2:]

# %%
#DATA SCIENCE SESSION 03 - 5TH FEB

#CODINGBAT PROBLEMS

#Warmup-1 > sleep_in
def sleep_in(weekday, vacation):
  if weekday == False or vacation == True:
    return True
  else:
    return False


#Warmup-1 > monkey_trouble
def monkey_trouble(a_smile, b_smile):
  if a_smile == b_smile:
    return True
  else:
    return False


#Warmup-1 > sum_double
def sum_double(a, b):
  if a == b:
    return (a+b) * 2
  else:
    return a+b


#Warmup-1 > diff21
def diff21(n):
  if n > 21:
     return (n-21)*2
  else :
     return 21-n


#Warmup-1 > parrot_trouble
def parrot_trouble(talking, hour):
  if talking == True and (hour< 7 or hour > 20):
    return True
  else :
    return False


#Warmup-1 > makes10
def makes10(a, b):
  if 10 in (a,b, a+b):
    return True
  else:
    return False



#Warmup-1 > near_hundred
def near_hundred(n):
  if abs(n-100) <=10 or abs(n-200)<=10:
    return True
  else :
    return False



#Warmup-1 > pos_neg
def pos_neg(a, b, negative):
  if negative == True :
    if a<0 and b<0 :
      return True
    else:
      return False
  else:
    if (a>0 and b<0) or (a<0 and b>0):
      return True
    else:
      return False



#Warmup-1 > not_string
def not_string(str):
  if str[0:3] == 'not':
    return str
  else:
    return 'not ' + str


#Warmup-1 > missing_char
def missing_char(str, n):
  return str[:n] + str[n+1:]

# %%
#DATA SCIENCE SESSION 04 - 6TH FEB

list =  [2,3,4,5,6,7,8]
print(list)

New = int(input("Enter : "))
list.append(New) #it alwasy add at the end
print ("updated List ; ",list)

Remove_item = int(input("Enter Item : "))
list.remove(Remove_item)
print("Updated List " , list)
search = int(input("Enter : "))

if search in list:
  print("you found")
else:
  print("not found")

length = int(input("enter length : "))
for i in range(length):
  New = int(input("Enter : "))
  list.append(New) #it alwasy add at the end
  print ("updated List ; ",list)


''''
Make a chatbot which can do these certain ask if asked add to add the elements till of length
remove
replace
exit
viewList
'''


list_data = []   # Initialize the list

print("welcome to the game ")
while True:
    choice = input("type - add/remove/replace/exit/viewList : ").lower()

    if choice == 'add':
        length = int(input("enter number of items to add : "))
        for i in range(length):
            new = int(input("Enter item to add : "))
            list_data.append(new)
        print("Updated List:", list_data)

    elif choice == 'remove':
        remove_item = int(input("Enter Item to remove : "))
        if remove_item in list_data:
            list_data.remove(remove_item)
            print("Updated List:", list_data)
        else:
            print(f"{remove_item} not found in the list.")

    elif choice == 'replace':
        old_value_index = int(input("Enter index of item to replace : "))
        if 0 <= old_value_index < len(list_data):
            new_value = int(input("Enter new value : "))
            list_data[old_value_index] = new_value
            print("Updated List:", list_data)
        else:
            print("Invalid index.")

    elif choice == 'viewlist':
        print("Current List:", list_data)

    elif choice == 'exit':
        print("Exiting the game. Goodbye!")
        break

    else:
        print("Invalid input, please try again!")



#CODINGBAT PROBLEM
#List-1 > first_last6

def first_last6(nums):
  return nums[0] == 6 or nums [-1] == 6
# Out:
# [2, 3, 4, 5, 6, 7, 8]

# %%
#DATA SCIENCE SESSION 05 - 9TH FEB

#Warmup-2 > string_times
def string_times(str, n):
  return str  * n

#Warmup-2 > front_times
def front_times(str, n):
  return str [0:3] * n

#Warmup-2 > string_bits
def string_bits(str):
   return str [0::2]

#Warmup-2 > string_splosion
def string_splosion(str):
  l = ''
  for i in range(len(str)):
    l = l + str[0:i:1]
  return l


#Tuples
my_tuple = (7,8,9,0)
print(my_tuple)



#Dictonary

student = {
    "name" : "Ria",
    "age" : 25,
    "course" : "python"
}

print(student["name"])

person = {
    "name" : "Ria",
    "age" : 21,
    "skils" : ['python', 'java'],
    "Gender" : 'Male'

}
print(person)



#Functions

def add (a,b):
  print(a+b)

a = int(input("enter : "))
b = int(input("enter : "))
add(a,b)


#divide

#write a program to make a calculator ( + * - / % **)
#if + call the add
#whole loop

def add_func(): # Renamed to avoid conflict with `add(a,b)` function above
  a = int(input("enter : "))
  b = int(input("enter : "))
  print(a+b)

def multiply_func(): # Renamed for clarity
  a = int(input("enter : "))
  b = int(input("enter : "))
  print(a*b)

def minus_func(): # Renamed for clarity
  a = int(input("enter : "))
  b = int(input("enter : "))
  print(a-b)

def divide_func(): # Renamed for clarity
  a = int(input("enter : "))
  b = int(input("enter : "))
  print(a/b)

while True:
  choice = input("type +,-,*,/,%,**: ")
  if choice =="+":
    add_func()
  elif choice == "-":
    minus_func()
  elif choice == "*":
    multiply_func()
  elif choice == "/":
    divide_func()
  else:
    print("Invalid choice, please try again.")
# Out:
# (7, 8, 9, 0)
# Ria
# {'name': 'Ria', 'age': 21, 'skils': ['python', 'java'], 'Gender': 'Male'}

# %%
#DATA SCIENCE SESSION 06 - 10TH FEB

student = {
    "Aman": [80,90,70,60],
    "Riya": [95,92,88,91],
    "Sam": [40,55,60,30]
}

topper = ''
top_average = 0
failed_students = [] # Corrected syntax for initializing an empty list and renamed for clarity

for name, marks in student.items():
  average = sum(marks) / len(marks) # Fixed typo: maeks -> marks
  grade = '' # Initialize grade for each student
  if average >= 90:
    grade = 'A'
  elif average >= 75:
    grade = 'B'
  elif average >= 60:
    grade = 'C'
  else: # Corrected logic to assign 'Fail' only if average is below 60
    grade = 'Fail'
    failed_students.append(name) # Append student to failed list only if they fail

  print(f"{name}'s average: {average:.2f}, Grade: {grade}") # Corrected print statement

  if average > top_average: # Changed >= to > to handle cases where multiple students have the same top score, picking the first one
    top_average = average # Corrected assignment operator
    topper = name

# Print topper and failed students outside the loop
print("\n--- Summary ---")
print("Topper :", topper, f"with an average of {top_average:.2f}")
print("Failed students :", failed_students)



account = {
    "Rachana" : 1000
}

while True :
  choice = input("type - deposit/ withdraw/check/exit :")
  if choice == 'deposit' :
    deposit_amount = int(input("Enter amount to deposit:"))
    account["Rachana"] = account['Rachana'] + deposit_amount
    print(f"Deposit successful. New balance: {account['Rachana']}")
  elif choice == 'withdraw':
    withdraw_amount = int(input("Enter amount to withdraw:"))
    if withdraw_amount <= account['Rachana']:
        account['Rachana'] = account['Rachana'] - withdraw_amount
        print(f"Withdrawal successful. New balance: {account['Rachana']}")
    else:
        print("Insufficient funds.")
  elif choice == 'check':
    print(f"Current balance for Rachana: {account['Rachana']}")
  elif choice == 'exit':
    print("Exiting banking application. Goodbye!")
    break
  else:
    print("Invalid choice, please try again.")
# Out:
# Aman's average: 75.00, Grade: B
# Riya's average: 91.50, Grade: A
# Sam's average: 46.25, Grade: Fail
#
# --- Summary ---
# Topper : Riya with an average of 91.50
# Failed students : ['Sam']

# %%
#DATA SCIENCE SESSION 07 - 11TH FEB

#Functions
#a function is a set of tasks we  can reuse or call it mant times.
#meaninful

def add():
  a = 4
  b = 4
  print("A+B =", a+b) # Corrected print statement
for i in range(2):
  add()


  def add():
    list = []
    l = int(input("Enter length: ")) # Corrected 'inut' to 'input'
    for i in range(l):
      value = int(input("Enter nUmber"))
      list.append(value)
      s = s + list[i]
    print(list)

    print('sum : ',s)
  add()


#Subtract func

def sub():
  list = []
  s = 0
  l = int(input("Enter Length :"))
  for i in range (l):
    value = int(input("Enter Number : "))
    list.append(value)
    f = list[0]
    s = sum (list[1:])
    s = f - s
    print(list)

    print('sub : ',s)
sub()

  #User - i want a enter 5 number show [ using List]
# Out:
# A+B = 8

# %%
#DATA SCIENCE SESSION 08 - 12TH FEB

#DICTIONARY - root divt where u can see the word

Person = {
    'name' : 'Rachana',
    'age': 21,
    'phone': '9742059666',
    'city' : 'Bangalore',
    'gender' : 'female'
}
#acess thr element from dict
print(Person['name'],Person['city'])

#update the element in the dict

Person['name'] = 'angel'
print(Person)
#removr thr kry value from the dict
Person.pop('name')
print(Person)

#accesss elements

print(Person.keys())
print(Person.values())
print(Person.items())


#check weather the user is present in your phonebook or not
#challenge - create phonebook

phonebook={
    "fareed" :1234567890,
    "riyan" :9899976,
    "sam" :89445657

}
while True:
  search = input("Enter nam eof the person : ")
  if search in phonebook:
    print(search," is present in phototbook")
  else:
    # Corrected the print statement for person.get
    print(f"{search} not found in phonebook.") # Simplified the message

  for keys,values in phonebook.items():
    print(keys, ': ',values)

  text = 'apple bannana apple kiwi'
  words = text.split() # Define 'words' by splitting the 'text'
  count = { }
  for i in words :
    count[i] = count.get(i,0) + 1
  print(count)

  # Corrected the dictionary initialization for 'data'
  data = {
          'student1' : {
              'name' : 'Rachana',
              'age': 21,
              'phone': '9742059666',
              'city' : 'Bangalore',
              'gender' : 'female'
          }
  }

  # This loop will now work correctly as 'data' is a valid dictionary
  for keys,value in data.items():
      print(keys, value)

  # Added a way to exit the while True loop, otherwise it runs indefinitely
  break # Or add a condition to break out of the loop
# Out:
# Rachana Bangalore
# {'name': 'angel', 'age': 21, 'phone': '9742059666', 'city': 'Bangalore', 'gender': 'female'}
# {'age': 21, 'phone': '9742059666', 'city': 'Bangalore', 'gender': 'female'}
# dict_keys(['age', 'phone', 'city', 'gender'])
# dict_values([21, '9742059666', 'Bangalore', 'female'])
# dict_items([('age', 21), ('phone', '9742059666'), ('city', 'Bangalore'), ('gender', 'female')])

# %%
#DATA SCIENCE SESSION 09 - 13TH FEB

#searching sorting stack queue and LinkedList

#searching
list = [2,3,4,5,6]
search = 6
if search in list:
    print("found")
else:
    print("not found")


#Linear searching - finding element by comparing each value with search value
list = [5,65,20,3,1,0,45,4,90]
search = int(input("Enter : "))

for i in range (len(list)):
    if search == list[i]:
        flag = False
        break
    if flag == True:
      print("you found at index" ,i)
    else:
        print("not found")

#sorting
list = [5,65,20,3,1,0,45,4,90]
for i on range(len(list)):
    for j in range (len(list)-1):
        if list[j]> list[j+1]:
            #swapping
            temp = list[j]
            list[j] = list[j+1]
            list[j+1] = temp
        print("sorted List :" ,list)
        search = int(input("Enter the search number "))
        flag = False
        left = 0
        right = len(list) - 1
        while left <= right:
            mid = (left + right) //2
            if list[mid] == search :
                print(" you found at index-", mid)
                flag = True
            elif list[mid]>search:
                right = mid-1
            else:
                left = mid + 1

         if flag  == True :
               print("you found at index-",mid)
            else:
                print("not found")

# %%
#DATA SCIENCE SESSION 10 - 15TH FEB

#ML MODELS

import numpy as np
#numerical computation
from sklearn.linear_model import LinearRegression
hours = np.array([1,2,3,4,8,10,12,15,17,20,22,24]).reshape(12,1)
marks = np.array([20, 30,40,50,60,80,90,95,89,98,99,100])
#train model
print(hours,marks)
 #train model
model = LinearRegression()
model.fit(hours,marks)
#prediction
user-input = int(input("how many hrs do u study :"))
output = model.pridict([user-input])
print('you get marks :', output)

if hours<=24 and output <=100:
  print('you get marks : ',output)
else:
  print('Invalid Error! : ')



#problem : based on your age output the height in cms or inches

age = np.array([1,2,3,5,10,20,30,40,50,60,77,8,90,100]).reshape(13,1)
heights = np.array([40,80,90,100,120,150,170,190,200,250,265,270,271])
#train model
print(age,height)
a train model
model = LinearRegression()
model.fit(age,height)
#prediction
user-input = int(input("how many hrs do u study :"))
output = model.pridict([user-input])
print('you get marks :', output)

if hours<=24 and output <=100:
  print('you get marks : ',output)
else:
  print('Invalid Error! : ')

# %%
#DATA SCIENCE SESSION 11 - 16TH FEB

#Numpy = Numerical python - complex numerical computation when u have large data
this faster than lists
-fixed datatype
-continous memeory allocation
-vectorization
-used in data science, data analyst , ai , ml

import numpy as np
a = np.array([1,2,3,4,5,6,7,8])
print(a)

#create numpy array and find even numbers


for i in range a:
  if i%2 == 0:
    print(i)

#reshape
a = np.array([1,2,3,4,5,6,7,8])
a = np.arange(1,13)
print(a.reshape(4,3))
#print(a[1:4])

#2dmarray
b = np.array([[1,2,3] ,[4,5,6]])
#print(b)



t = 0
nums = np.array([ [1,2,3,4,5,6,7],[2,3,4,5,6,7,8] ])
for i in nums:
  t = t + i
print(t)
sum = 0
for i in t:
  sum = sum +i
print(sum)

#print(np.sum(nums))

create a project
1. spam, dector
if spam works > 10 - output spam [1]
else 0 no spam

2. marks > = 35 pass
else fail


nums = np.array([ [1,2,3,4,5,6,7],[2,3,4,5,6,7,8] ])
print(nums.shape)
print(nums.ndim) #dimension

print(nums.dtype)
print(a.size)

# %%
#DATA SCIENCE SESSION 12 - 17TH FEB

#Numpy
'''
sort nd search element in numpy array
arr = [7890,90,7,3,2,67,0,58,9,800]
search = 0
Binary searchin
'''

import numpy as np
list = np.array([7890,90,7,3,2,67,0,58,9,800])
#sort
for i in range (len(list)):
  for j in range (len(list)-i-1):
    if list[j]> list [j+1]:
      #swapping
      temp = list[j]
      list[j] = list[j+1]
      list[j+1] = temp
print("sorted List : " , list)
search = int(input("Enter the search number "))
search = int(input("Enter the search number "))
flag = False
left = 0
right = len(list)-1
while left <= right :
  mid = (left + right) //2
  if list [mid] == search:
    # In a binary search, if the element is found, you typically set flag to True and record the index, then break or adjust bounds.
    # The original code had an issue here where it would set right = mid - 1 even if found, which is for continuing the search for first occurrence.
    # For a simple 'found' check, a break is sufficient.
    flag = True
    print("you found at index-" , mid)
    break # Exit loop once found
  elif list [mid]>search:
    right = mid -1
  else:
    left = mid + 1

  if flag == True :
    # This part was problematic as 'mid' would be from the last iteration and not necessarily where the element was found.
    # Also, it was outside the main if/elif/else block for search.
    # The print should occur when found, or after the loop if not found.
    pass # Handled above
else: # This else belongs to the while loop, executes if loop finishes without 'break'
  if not flag:
    print("not found")




import numpy as np
#numerical computation
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

hours = np.array([1,2,3,4,8,10,12,15,17,20,22,24]).reshape(12,1)
marks = np.array([20, 30,40,50,60,80,90,95,89,98,99,100])
#train model
print(hours,marks)
 #train model
model = LinearRegression()
model.fit(hours,marks)

#prediction
# user-input was not defined for the first LinearRegression model prediction.
# Assuming it should be defined before use or is meant for a user prompt.
# Correcting `pridict` to `predict`
user_input = int(input("how many hrs do u study :")) # Added user input for prediction
output = model.predict([[user_input]]) # Corrected 'pridict' to 'predict' and format for single prediction
print('you get marks :', output)

plt.scatter(hours,marks,color='blue') # Corrected 'sactter' to 'scatter' and 'colour' to 'color'
plt.plot(hours,model.predict(hours),color='red') # Plotting the regression line over the original hours
plt.xlabel('hours')
plt.ylabel('marks')
plt.title('marks predictor') # Corrected 'pedictor' to 'predictor'
plt.show()


marks = np.array([25,35,40,50])
x = np.where(marks == 3)
print(x)
Updated_marks = marks[[True, False, True , False, True , False]]
print(Updated_marks)
# Out:
# sorted List :  [   0    2    3    7    9   58   67   90  800 7890]

# %%
#DATA SCIENCE 13 SESSION - 18TH FEB

#Pandas-
#insights - important info

import pandas as pd

data = {
    "age" : [23,34,56,56,78],
    "name" : ['sam','pam', 'ram','van', 'yan'],
    "Marks" : [200,30,200,300,None],
    'city' :['big', 'chennai','mumbai','delhi','pune'],
    'country': ['India','US', 'UK','Europe',],
    'IDNumber' : [None, 204,205,206,207]
}

df = pd.DaraFrame(data)
print(df)

#Slicing
print(df.iloc[0:5])

#filter data on condition

x = df[df['Marks'] > 100]
print('\n', x)

x= df[df['city'] == 'delhi' ]
print('\n',x)

x = df(['city'] == 'delhi') | (df['Marks'] > 100)
print('\n',x)

#calclations

x = df['Marks'].mean()
print('\n',x)

x = df['Marks'].max()
print('\n',x)
x = df['Marks'].sum()
print('\n',x)
x = df['Marks'].count()
print('\n',x)


#data sorting

x = df.sort_valeus('city', ascending = False)
print('\n',x)

#grouping average marks by city
x = df.groupby('city')['Marks'].mean()
print("\n",x)

#Adding the new columns
x = df['grade'] = ['b','d','c','a','a']
print("\n",x)
print(df)

#finding the missing value
x = df.isnull().sum()
print("\n",x)

x = df.fillna(200)
print("\n",x)

x = df.dropna()
print("\n",x)

'''
craete dataset for:
employees
salary
department
experiment

then:
find average salary
height paid employee
department wise salary avrage
'''

#which types of passangers were more likely to survive ?
df = pd.read_csv('titanic.csv')
df.head()
df.tail()

print(df.colums)
print(df.info())
print(df.describe())

# %%
#DATA SCIENCE SESSION 14 - 19TH FEB

#Numpy functions
#copy and view

import numpy as np
nums = np.array([9, 6, 7, 4, 3, 90]) # Corrected: Numbers should be separated by commas

print(nums)

#copy - a copy func copy the real array but whatever changes u make in real array wont impact copy array

x = nums.copy() # Corrected: Call the copy method to create a copy of the array
nums[0] = 89
print(x,nums)

#view - its a copy of real array but when u make changes in original array it makes in the view array as well
x = nums.view()
nums[0] = 788
print(x,nums)


#shape

nums = np.array([9,6,7,4],[45,545,245,24])
print(nums.shape)
print(nums.reshape(-1))

#-1 use to convert 2d arr to 1d arr


#iterating
for i in nums:
  for j in i:
    print(j)


for i in np.nditer(numpy):
      print(i)
n1 = np.array([[9,6,7,4],[45,545,245,24]])
n2 = np.array([[9,6,7,4],[45,545,245,24]])

x = np,concatenate((n1,n2), axis = 1)
print(x)


'''
axis 0 = row wise addition
axis 1 - column wise addition
'''


#split
n1 = np.array (  [2,3,4,5,6,7])
x = np.array_split(n2,4)
print(x)


#search and sort
x = np.sort(n1)
print(x)

#where and searchsort()
x = np.where(n1 == 33)
print(x)

x = np.searchsorted(n1,8)
print(x)



#pandas - its a library use to do analysis
'''
working with tables
clean data
analyze data
filter data
summary of the data
'''

import pandas as pd

data = {
    'name':['shiv','sam','max','caire'],
    'age':[54,89,90,78,67],
    'marks':[7,8,9,3,4],
    'country': ['India','Japan','Germany','UK']
}
df = pd.DataFrame(Data)
print(x)


#pandas - its a library use to do analysis
# Out:
# [ 9  6  7  4  3 90]
# [ 9  6  7  4  3 90] [89  6  7  4  3 90]
# [788   6   7   4   3  90] [788   6   7   4   3  90]

# %%
#DATA SCIENCE 15 SESSION  - 20TH FEB

#Which types of passengers were more likely to survives?
#what factor affect the survival
import pandas as pd

df = pd.read_csv('Titanic.csv')
df.head()
df.tail()
print(df)
print(df.columns)
print(df.info())
print(df.describe())

df.rename(columns = {'sex' : 'gender'} , inplace = True )
df.columns

#data cleaning
print(df.isnull().sum())

df.drop(columns = ['Cabin'],inplace = True)
print(df.head(500))

'''
x = df.fillna({'Age' : 'unknown'},inplac4 = True)
print(df.isnull().sum())
df.head(500)
'''

y = df['Age'].median()
print(y)
y = df['Embarked'].mode()
print(y)

'''
x = df['Age'].fillna(df['Age'].median(),inplace = True)
print(df.insull(),sum())
df.head(500)

x = df['Embarked'].fillna(df['Embarked'].mode(),inplace = True)
print(df.insull(),sum())
df.head(500)

'''


#problem 1
x = df.group('gender')['survived'].sum()
print('people survived \n ', x)


#problem 2
x = df.group('Pclass')['survived'].mean()
print('people survived \n ', x)


#save it as a new file

df.to_csv('titanic_cleaned.csv' , index = False)


#matplotlib graphs
#dataset from kaggle - data analysis (sales marketing, finance)
#plotting the graphs

import matplot.pyplot as plt
import seaborn as sns

sns.barplot(x = 'gender', y = 'survived', data = df)
plt.title('survival by the gender')

plt.show()


sns.histplot(df['Age'], bins = 20)
plt.title('Age distribution')
plt.show()

# %%
#DATA SCIENCE SESSION 16 - 23rd FEB

#Netflix data

'''
Analyze netflix data to understand content growth and type distribution (movies vs tv shows) and country contribution
1. how many total tit;es are on netflix
2. movies vs tv shows
3. content grown over time (how)?
4. which countries produces more content
5. what are the most common genre
'''

from google.colab import files
uploaded = files.upload()

import pandas as pd
df = pd.read_csv('netflix1.csv')
df.head()

df.info()
df.columns
df.describe()


#data cleaning

print((df == 'Not Given').sum())
df = df.replace('Not Given', pd.NA)
print((df == 'Not Given').sum())
df.isnull().sum


df.head(20)
#filling the values
df['country'] = df['country'].fillna('None')
df['director'] = df['director'].fillna('None')
df.isnull().sum()



#convert date to real datetime
df['date_added'] = pd.to_datetime(df['date_added']) # Corrected column name to 'date_added'
#extreact year
df['year'] = df['date_added'].dt.year
df.head() # Corrected typo from haed() to head()

#analysis we want to how many types of titles there
total_titles = df.shape[0]
print("Total Tiles:", total_titles)

#p2
print(df['type'].value_counts())

import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x = 'type' , data = df)
plt.title('movies vs tv shows')
plt.show()

year_counts = df['year'].value_counts().sort_index()

plt.figure(figsize=(10,5))
year_counts.plot(kind='line')
plt.title("Content Added Over Years")
plt.xlabel("Year")
plt.ylabel("Number of Titles")
plt.show()

#p4
top_countries = df[ 'country']. value_counts () .head (10)
plt. figure(figsize=(10,5))
sns .barplot(x=top_countries.values, y=top_countries.index)
plt. title("Top 10 Content Producing Countries")
plt. show()

##p5
top_genres = df['listed_in'].value_counts().head (10)

plt.figure(figsize=(10,5))
sns.barplot(x=top_genres.values, y=top_genres.index)
plt. title("Top 10 Genres")
plt. show()
# Out:
#      <input type="file" id="files-664e976f-b27c-4ac8-bc01-b52c81ab69b6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-664e976f-b27c-4ac8-bc01-b52c81ab69b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls /content/
# Out:
# sample_data

# %%
#DATA SCIENCE SESSION 17 - 24TH FEB

#Plotty

import pandas as pd
import plotly.express as px

df = pd.read_csv('/content/netflix_titles.csv')

fig = px.histogram(
    df,
    x = 'release_year',
    color = 'type',
    animation_frame = 'release_year',
    title = 'Netflix content over years'
)
fig.show()

# Prepare data for the bar chart
grouped_df = df.groupby(['release_year' , 'type']).size().reset_index(name = 'count')

fig = px.bar(
    grouped_df,
    x = 'release_year',
    y = 'count',
    color = 'type',
    title = 'Netflix content by year'
)

fig.update_layout(
    updatemenus=[
        dict(
            type="buttons",
            direction="down",
            showactive=True,
            buttons=list([
                dict(
                    label = 'all',
                    method = 'update',
                    args = [{'visible' : [True, True]}] # Show both movie and TV show traces
                ),
                dict(
                    label = 'movies',
                    method = 'update',
                    args = [{'visible' : [True, False]}] # Show only movie trace
                ),
                dict(
                    label = 'tv shows',
                    method = 'update',
                    args = [{'visible' : [False, True]}] # Show only TV show trace
                ),
            ])
        )
    ]
)

fig.show()



'''
#6) which rating is most common
#7. which genre dominates in india vs Us
#9. top 10 directors iwth most titles
10 can we pedict wheather a title will be a movie or tv show
11 can we predict rating based on genre
12 compare content count before 2016 vs tv shows
13 calculate growth percentagw
14 avg duration of movies vs tv shows
15 which month does netflix add more content
'''

filtered - df[df['country']].isim['India','United states']
genre_country = (filtered.assign(genre=filtered['listed_in'].str.split(',')).explode('Genre').groupby(['country','Genre']).size().reset_index(name = 'count'))

fig = px.bar(
    genre_country,
    x = 'Genre',
    y = 'Count',
    barmode = 'group'
    title = 'India vs us'
)

fig.update_layout(xaxis_tickangle = (-45))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#DATA SCIENCE SESSION - 18 - 25TH FEB


WORKED ON EXCEL SHEET

# %%
#DATA SCIENCE SESSION 19 - 26TH FEB

#predict the loan is approved or not

from sklearn.linear_model import LogisticRegression
import numpy as np
data = np. array([
  [25000,500],
  [45000, 6001],
  [55000, 700],
  [15000,500],
  [35000,550],
  [35000,500],
  [75000,800]
])
y = np.array([0,1,1,1,0,0,1])
model = LogisticRegression()
model.fit(data,y)
pre = model.predict([[45000,600]])
print(pre)


from sklearn.linear_model import LogisticRegression
import numpy as np
data = np.array([
  [25, 120, 80, 90],
  [45, 140, 90, 130],
  [50, 150, 95, 160],
  [30, 110, 75, 85],
  [60, 170, 100, 180],
  [35, 130, 85, 120],
  [55, 160, 98, 170],
])
y = np.array([0, 1, 1, 0, 1, 0, 1])
model = LogisticRegression()
model.fit(data, y)
new_patient = [[48, 145, 92, 150]]
prediction = model.predict(new_patient)
print(prediction)


TYPES OF LOGISTICS REGRESSION
1. BIONOMIAL - Dependent variable , has only 2 possibilites yes or no , fail or pass etc
2. MULTINOMIAL LOGISTIC REGRESSION - Dependent variable has two or more possibilites - classifying dog/cat/hen
3.ORDINAL LOGISTIC REGRESSION - Depent variable has 3 or more category
# Out:
# [0]
# [1]

# %%
#DATA SCIENCE SESSION 20- 27TH FEB

#MONTHLY TASK -
#1. Report of what u studies in 20 session
#2. create one project based on your choice take help from notes and resources
#3. cover all the topics - pandas numpy create excel dashboard used logistic regression , create one project covering all these

#2
#Student performance dataset using muktinomial regression do classification and regression

#multinomial Regression

#predict the height based on the age



import numpy as np
from sklearn.linear_model import LogisticRegression
import pandas as pd
#data
ages = np.array([2,5,7,10,12,14,16,18,20]).reshape(9,1)
height = np.array ([74,84, 75, 110, 115, 105, 130, 150, 1451])
print(ages,height)

hclass = []
for i in height:
   if i < 100:
      hclass. append (0) #short
   elif i <=130:
      hclass. append (1) #tall
   else:
      hclass.append (2) #tallest

hclass = np. array(hclass)

model = LogisticRegression()
model. fit(ages, height)

import matplotlib.pyplot as plt
plt.figure (figsize = (8,5))
plt.scatter(ages,height,c = hclass, cmap ='viridis',s = 100)
plt.xlabel('age')
plt.ylabel ('height')
plt.title('Relistic age vs height')
plt.colorbar()
plt.show()



age_range = np.linspace(4, 19,200).reshape(-1,1)
pre = model.predict(age_range)
for i in range(len(pre)-1):
   if pre[i] != pre[i+1]:
     print('boundry near age' ,age_range [i])

import matplotlib.pyplot as plt
plt.figure(figsize = (8,5))
plt.scatter(ages,height, c = hclass,cmap = 'viridis',s = 100)
plt. plot(age_range, pre, color= 'red')
plt.xlabel('age')
plt.ylabel('height')
plt. title('Relistic age vs height')
plt. colorbar()
plt. show()
# Out:
# [[ 2]
#  [ 5]
#  [ 7]
#  [10]
#  [12]
#  [14]
#  [16]
#  [18]
#  [20]] [  74   84   75  110  115  105  130  150 1451]
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# boundry near age [4.15075377]
# boundry near age [6.56281407]
# boundry near age [8.67336683]
# boundry near age [10.93467337]
# boundry near age [13.04522613]
# boundry near age [14.92964824]
# boundry near age [16.5879397]
# boundry near age [18.0201005]

# %%
#SESSION 20 - CONTINUE

'''
Use Cases:
Predict wine quality using regression or classification models
Explore correlations between chemical properties and taste
Benchmark feature engineering and model tuning techniques
Create visualizations for educational or storytelling purposes
'''



import pandas as pd
df = pd.read_csv('winequality-red.csv')
df.head()

print(df.isnull().sum)
print(df.duplicated().sum())

df.columns = df.columns.str.strip()

import matplotlib.pyplot as plt
df['quality'].value_counts().sort_index().plot(kind = 'bar')
plt.show()
# Out:
# <bound method DataFrame.sum of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %%
#DATA SCIENCE SESSION 21 - 1ST MARCH

#Clean the data and see if u have any null or duplicate values



from google.colab import files
uploaded = files.upload()

import pandas as pd
df = pd.read_csv("student_performance_updated_1000 1.csv")
df.head()

print("Dataset Shape:", df.shape)
print (df.head())

df = df.drop(columns=["StudentID", "Name"])

print ("\nMissing Values Per Column:")
print(df.isnull().sum())

duplicates = df.duplicated().sum()
print ("InDuplicate Rows:", duplicates)

df = df.drop_duplicates()

print ("Shape After Removing Duplicates:", df.shape)


#filling the missing values
for col in df.columns :
  if df[col].dtype in ['int64', 'float64']:
    med_val = df[col].median()
    df[col] = df[col].fillna(med_val)
  else:
    mode_val = df[col].mode()[0]
    df[col] = df[col].fillna(mode_val)

print("\nMissing Values Per Column:")
print(df.isnull().sum())


# Gender → Binary Encoding
df ["Gender"] = df[ "Gender"]. map({"Male": 0, "Female": 1})

df["Online Classes Taken"] = df["Online Classes Taken"].astype(int)

df[ "ParentalSupport"] = df["ParentalSupport"]. map({
"LOW": 0,
"Medium": 1,
"High": 2
})


def categorize(score) :
   if score < 60:
     return 0 #Low
   elif score < 80:
     return 1 # Medium
   else:
     return 2 # High

df["Performance_Level"] = df["FinalGrade"].apply (categorize)
# Out:
#      <input type="file" id="files-f3592c02-5dd2-4f21-907c-f679f852620f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f3592c02-5dd2-4f21-907c-f679f852620f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#DATA SCIENCE  SESSION - 22,23,24 - THERORY

# %%
#DATA SCIENCE SESSION 25 - 9TH MARCH

#HEALTH INSURANCE PREDICTION

#LINEAR REGRESSION

#Problem Statement
#The goal of this project is to develop a predictive model that accurately estimates the medical insurance costs for individuals based on various demographic, lifestyle, and health-related factors.
#By applying machine learning techniques,
#we aim to assist insurance companies in better understanding their risk profiles
#and help individuals gain insights into how different factors influence their insurance premiums.


from google.colab import files
uploaded = files.upload()

#Import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


#load the data
data = pd.read_csv('insurance (1).csv')
data

#Domain Analysis The descriptions of the variables based on the insurance dataset:

#Age
#Description: Age of the primary beneficiary covered by health insurance.
#Type: Continuous numerical variable.

#Sex
#Description: Gender of the insurance contractor.
#Type: Categorical variable with two levels: female, male.

#BMI (Body Mass Index)
#Description: Body mass index, which is a measure of body fat based on height and weight.
#Type: Continuous numerical variable.
#Ideal Range : Random between 18.5 to 24.9 kg/m².

#Children
#Description: Number of children covered by health insurance or number of dependents.
#Type: Discrete numerical variable.

#Smoker
#Description: Binary indicator if the beneficiary is a smoker.
#Type: Categorical variable with two levels: yes, no.

#Region
#Description: The beneficiary's residential area in the US.
#Type: Categorical variable with four levels: northeast, southeast, southwest, northwest.

#Charges
#Description: Individual medical costs billed by health insurance.
#Type: Continuous numerical variable.


#BASIC CHECKS

# shape : gives number of rows and columns
data.shape

# head: print first 5 rows
data.head()

# tail : print last 5 rows
data.tail()

# info: memory usage
data.info()

# print all columns
data.columns

# check the data type
data.dtypes

# check the data type
data.dtypes

# print categorical columns
cat_col= data.select_dtypes(include=['object'])
cat_col

# statiscal report for numerical column
data.describe()

# statiscal report for categorical column
data.describe(include='object')

# find unique values in categorical column
for x in cat_col:
  print(x,'-->',data[x].unique())

  # find value counts
for x in cat_col:
  print(data[x].value_counts())
  print()



#DATA CLEANING

#check for missing values
data.isnull().sum()

#Clearly no missing values.

#Check for duplicates

# duplicates : repeated values
data.duplicated().sum()

#There is 1 duplicate which has to be dropped.

# drop duplicates
data.drop_duplicates(inplace=True)

data.duplicated().sum()



#EXPOLORATORY DATA ANALYSIS
#Univariate Analysis

#Analysing single column

#1,Histogram
#2.countplot
#3.box plot


# Check the distribution of charges
plt.figure(figsize=(5,2))
sns.histplot(data,x='charges',kde=True,color='yellow')
plt.show()

# Check the distribution of age
plt.figure(figsize=(5,2))
sns.histplot(data,x='age',kde=True,color='pink')
plt.show()

#Check the distribution of bmi
plt.figure(figsize=(5,2))
sns.histplot(data,x='bmi',kde=True,color='orange')
plt.show()

# Visualise count of male and female
plt.figure(figsize=(5,2))
sns.countplot(data , x='sex')
plt.show()

# Visualise count of smokers and non smokers
plt.figure(figsize=(5,2))
sns.countplot(data , x='smoker')
plt.show()

# Visualise count of different region
plt.figure(figsize=(5,2))
sns.countplot(data , x='region')
plt.show()

# count of children
plt.figure(figsize=(5,2))
sns.countplot(data , x='children')
plt.show()

# check are there any outliers in age
plt.figure(figsize=(5,2))
sns.boxplot(data,x='age')
plt.show()

# check are there any outliers in bmi
plt.figure(figsize=(5,2))
sns.boxplot(data,x='bmi')
plt.show()

# # check are there any outliers in charges
plt.figure(figsize=(5,2))
sns.boxplot(data,x='charges')
plt.show()



#BIVARIATE ANALYSIS
#Analysing two variables/columns

#1.scatter
#2.bar plot
#3.line plot

# find relationship between age and charges
plt.figure(figsize=(5,2))
sns.scatterplot(data,x='age',y='charges')
plt.show()

# find relationship between bmi and charges
plt.figure(figsize=(5,2))
sns.scatterplot(data,x='bmi',y='charges')
plt.show()

# find how charges vary with gender
plt.figure(figsize=(5,2))
sns.barplot(data,x='sex',y='charges')
plt.show()

# find how charges vary with smokers
# find how charges vary with gender
plt.figure(figsize=(5,2))
sns.barplot(data,x='smoker',y='charges')
plt.show()

 # find how charges  vary with children
# find how charges vary with gender
plt.figure(figsize=(5,2))
sns.barplot(data,x='children',y='charges')
plt.show()


# find how charges vary with region
# find how charges vary with gender
plt.figure(figsize=(5,2))
sns.barplot(data,x='region',y='charges')
plt.show()

data


#MULTIVARIATE ANALYSIS

# PAIRPLOT and heat map
sns.pairplot(data)

#heatmap
num_col = data.select_dtypes(include=np.number) # Define num_col by selecting numerical columns
corr = num_col.corr()
sns.heatmap(corr,annot = True)
# Out:
#      <input type="file" id="files-f15d5750-42cd-4871-8d98-ec278f33c8d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f15d5750-42cd-4871-8d98-ec278f33c8d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#DATA SCIENECE SESSION 26 - 10TH MARCH


from google.colab import files
uploaded = files.upload()


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


data = pd. read_csv( 'telecom_churn_data.csv')
data

#check data type of column
data.loc [:, 'gender'].dtype

data. loc[:, 'gender'].isnull().sum()

# since data type of gender is object (text)
# replace with mode
data.loc [:, 'gender'].mode()[0]



#using fillna will replace missing values with mode
data.loc [:, 'gender'] = data.loc[:, 'gender']. fillna(data.loc [:,'gender'].mode()[0])



#PAPERLESS BILLING

#check the data type
data.loc[:,'PaperlessBilling'].dtype

#find mode
data.loc[:,'PaperlessBilling'].mode()[0]


# fill with mode
data.loc[:,'PaperlessBilling']=data.loc[:,'PaperlessBilling'].fillna(data.loc[:,'PaperlessBilling'].mode()[0])

data.loc[:,'PaperlessBilling'].isnull().sum()




#MONTHLY CHARGES
# check data type
data.loc[:,'MonthlyCharges'].dtype

# If numeric check the distribution
# histogram
plt.figure(figsize=(5,2))
sns.histplot(data,x='MonthlyCharges',kde=True)
plt.show()


# Find skew
# skew = [-0.5,0.5]---> normal
# skew > 0.5 --> right skew
# skew <-0.5 --->left skew
data.loc[:,'MonthlyCharges'].skew()

#Since skewness is within [-0.5,0.5] the distribution of MonthlyCharges is normal. We have to replace missing value with mean.

# find mean
data.loc[:,'MonthlyCharges'].mean()

# replace with mean
data.loc[:,'MonthlyCharges'] = data.loc[:,'MonthlyCharges'].fillna(data.loc[:,'MonthlyCharges'].mean())

data.loc[:,'MonthlyCharges'].isnull().sum()



#TOTAL CHARGES
# check the data type
data.loc[:,'TotalCharges'].dtypes

#Since data type of Total charges is object though it has a numeric values. We have to do typecasting to convert object to float64.
#astype : Used to convert one data type into other if column has no missing values.
#pd.to_numeric : Used to convert data type of column into other data type when there are missing values in data

# Type casting: converting one data type to other
data.loc[:,'Total_Charges'] = pd.to_numeric(data.loc[:,'TotalCharges'],errors='coerce')
# coerce : converts empty string to null/nan

data.loc[:,'Total_Charges'].dtypes

# drop the old column
data.drop(columns='TotalCharges',inplace=True)

# check distribution
plt.figure(figsize=(5,2))
sns.histplot(data,x='Total_Charges',kde=True)
plt.show()

# find skew
data.loc[:,'Total_Charges'].skew()

# clearly skewness is greater than 0.5 , the distribution is right skewed
# find median
data.loc[:,'Total_Charges'].median()

# fill with median
data.loc[:,'Total_Charges']=data.loc[:,'Total_Charges'].fillna(data.loc[:,'Total_Charges'].median())

data.isnull().sum()
# Out:
#      <input type="file" id="files-2fee1d44-d697-4755-ad7d-97fee10fc209" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2fee1d44-d697-4755-ad7d-97fee10fc209">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#DATA SCIENCE SESSION 27 - 11TH MARCH

#INSURANCE DATATSET
#HANDELING OUTLIERS

#Outliers are extreme values which are far away actual data.
#Eg: Age of students:[20,22,23,24,25,40,98,100,160]
#In this case 98,100,160 are outliers

#1.How to Check outliers
#boxplot : Tells about the existence and direction of outliers
#scatter plot
#histogram

#2. How to find Outliers
#IQR (Interquartile range) : Used when data distribution is skewed.
#3-sigma rule : Used when data distribution is normal
#Outliers can be handled only if % of outliers is very less or less than 5%.

#3. IQR
#IQR Should be used when data distribution is skewed.

#Find Q1
#Find Q3
#Find IQR = Q3-Q1
#Find lower_limit = Q1-1.5*IQR
#Find upper limit = Q3+1.5*IQR
#Any value which is greater than upper limit and less than lower limit is considered as outlier.



#Check outliers in numerical columns

from google.colab import files
uploaded = files.upload()

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('insurance (1).csv')

fig,ax=plt.subplots(1,3,figsize=(6,2))
sns.boxplot(data,x='age',ax=ax[0])
sns.boxplot(data,x='bmi',ax=ax[1])
sns.boxplot(data,x='charges',ax=ax[2])
plt.tight_layout()

#Clearly it shows that bmi and charges have outliers towards right.
#Check the distribution of bmi and charges

fig,ax=plt.subplots(1,2,figsize=(6,2))
sns.histplot(data,x='charges',ax=ax[0],kde=True)
sns.histplot(data,x='bmi',ax=ax[1],kde=True)
plt.tight_layout()

# skewness of bmi and charges
data.loc[:,'bmi'].skew()
# bmi distribution is normal

data.loc[:,'charges'].skew()
# charges distribution is skewed


#IQR methods for Charges
#Since distribution is skewed


Q1 = data.loc[:,'charges'].quantile(0.25)
Q3 = data.loc[:,'charges'].quantile(0.75)
IQR = Q3-Q1
lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

# filter values greater than upper_limit
data[data.loc[:,'charges']>upper_limit]

# filter values less than lower_limit
data[data.loc[:,'charges']<lower_limit]

# filter values greater than upper limit , less than lower limit
data[(data.loc[:,'charges']>upper_limit) | (data.loc[:,'charges']<lower_limit)]

# percentage
len(data[(data.loc[:,'charges']>upper_limit) | (data.loc[:,'charges']<lower_limit)])/len(data)*100



#3 - sigma rule
#We use 3-sigma rule for BMI as its distribution is normal

#find mean
#find standard deviation
#find lower limit = mean-3*std
#find upper limit = mean + 3* std
#filter values greater than upper limit or less than lower limit is considered as an outliers.


mean_val = data.loc[:,'bmi'].mean()
std_val = data.loc[:,'bmi'].std()
lower_limit = mean_val - 3* std_val
upper_limit = mean_val + 3* std_val # Corrected typo: std_va to std_val

# filter values greater than upper limit
data[data.loc[:,'bmi']>upper_limit]

# filter values less than lower limit
data[data.loc[:,'bmi']<lower_limit]

len(data[(data.loc[:,'bmi']>upper_limit)|(data.loc[:,'bmi']<lower_limit)])/len(data)*100

#Since % of outliers was less than 5% we replace it with mean as its distribution was normal.


# replace with mean
data.loc[data.loc[:,'bmi']>upper_limit,'bmi']=data.loc[:,'bmi'].mean()

data[data.loc[:,'bmi']>upper_limit]





#Encoding Technique
#The process of converting text to numbers so a machine can understand.

#1.Label Encoder
#2. one hot encoder
#3. manual encoder
#4. Target encoder
#5. ordinal encoder


#Label Encoder
#Label encoder converts text to a numbers. It assigns unique numbers from 0 to each value based on alphabetical order.

# yes - 1
# No - 0

# red - 2
# green - 1
# blue - 0

# UG  - 2
# PG - 0
# PHD - 1

# male -1
# female - 0

# label Encoder should not be when we need to consider order or priority

# Smoker has values like Yes /No so will use label Encoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data.loc[:,'Smoker']= le.fit_transform(data.loc[:,'smoker'])

data.drop(columns='smoker',inplace=True)


#ONE HOT ENCODER
# scaling : minmax,standard

data
# Out:
#      <input type="file" id="files-7c33a85d-4824-4a6b-b950-7f9240a8cbbe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7c33a85d-4824-4a6b-b950-7f9240a8cbbe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#DATA SCIENCE SESSION 28 - 12TH MARCH


from google.colab import files
uploaded = files.upload()

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import LabelEncoder

data = pd.read_csv('insurance (1).csv')


#Manual Encoder
#Based on domain knowledge or priority we can encode manually.

# PG :1
# UG:0
# PHD:2


#ORDINAL ENCODER
#Assign values according to the order

#1. High : 2
#2. average:1
#3. Low:0

#TARGET ENCODER
#Check relationship between column and target. Based on analysis and based on which category has highest importance with target then assign values accordingly



# region
# region, charges

plt.figure(figsize=(5,2))
sns.barplot(data,x='region',y='charges')
plt.show()


data.loc[:,'Region']=data.loc[:,'region'].map({'southwest':0,'northwest':1,'northeast':2,'southeast':3})

data.drop(columns='region',inplace=True)

# Smoker was already encoded, but 'sex' needs to be encoded too.
le = LabelEncoder()
data.loc[:,'sex'] = le.fit_transform(data.loc[:,'sex'])
# Encode smoker column
data.loc[:,'smoker'] = data.loc[:,'smoker'].map({'no':0,'yes':1})


#SCALING
#If numerical columns has lot of variations among values then we use scaling just to bring all values to a same scale.

# 1. Min max scaler
# 2. Standard Scaler

#Min max scaler
#It will normalize all values in numerical columns into a range of 0 to 1.

df = data.copy()

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[['age']]= scaler.fit_transform(df[['age']])
df[['bmi']]= scaler.fit_transform(df[['bmi']])


#STANDARD SCALER
#It transforms all the values in a column such that mean = 0 and std = 1.

df1 = data.copy()

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df1[['age']]= scaler.fit_transform(df1[['age']])
df1[['bmi']]=scaler.fit_transform(df1[['bmi']])


#LOG TRANSFORMATION
#In regression model assume target variable to be normally distributed.Log transformation is used to convert skewed data into normal.

# charges
plt.figure(figsize=(5,2))
sns.histplot(df,x='charges',kde=True)
plt.show()

df.loc[:,'charges']=np.log(df.loc[:,'charges'])

plt.figure(figsize=(5,2))
sns.histplot(df,x='charges',kde=True)
plt.show()



#FEATURE ENGINEERING
#1.Selecting features
#2.drop columns
#3.create columns

df



#Split data for x and y
x = df.drop(columns='charges')
y= df['charges']


#Split data for training as well testing
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)


#Linear Regression
# import the model
from sklearn.linear_model import LinearRegression
# initialise the model
model = LinearRegression()
# train model : x_train,y_train
model.fit(x_train,y_train)

# make predictions
y_pred = model.predict(x_test)

# Slope
print(model.coef_)

# intercept
print(model.intercept_)



#EVALUATE THE LINEAR REGRESSION

#Mean Squared error
from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_absolute_percentage_error

# y_test,y_pred
mean_squared_error(y_test,y_pred)

#Mean absolute error
mean_absolute_error(y_test,y_pred)

#Root Mean squared Error
np.sqrt(mean_squared_error(y_test,y_pred))

#Mean Absolute Percentage Error
mean_absolute_percentage_error(y_test,y_pred)


#MARCH 13TH - 29 session

#R2 score
from sklearn.metrics import r2_score
r2= r2_score(y_test,y_pred)
r2

#Adjusted r2 score
n= x_test.shape[0]
n # number of rows

p= x_test.shape[1]
p #number of features

adj = 1 - (1-r2)*(n-1)/(n-p-1)
adj
# Out:
#      <input type="file" id="files-d67e3be7-5a4f-42f9-9624-881ce77316cf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d67e3be7-5a4f-42f9-9624-881ce77316cf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#DATA SCIENCE 29 SESSION - 13TH MARCH

#LOGISTICS REGRESSION THEORY
# Out:
#      <input type="file" id="files-84128746-e23f-494d-841a-5ac71143f054" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-84128746-e23f-494d-841a-5ac71143f054">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#DATA SCIENCE 30 SESSION - 14TH MARCH

#LOGISTICS

#HEART ATTACK RISK CLASSIFICATION



#Problem Statement
#The goal of this project is to develop a classification model that can predict the likelihood of a heart attack based on various patient health indicators.
#The dataset contains information on patients' demographic details, medical history, and diagnostic measures.
#The primary objective is to accurately classify patients into
#two categories: those with a higher likelihood of experiencing a heart attack (target = 1) and
#those with a lower likelihood (target = 0).




from google.colab import files
uploaded = files.upload()


#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


#load data
data = pd.read_csv('heart (1).csv')
data




#Understanding Variables

#Age – Age of the patient in years.
#Sex – Gender of the patient (M = Male, F = Female).
#ChestPainType – Type of chest pain experienced by the patient.
#RestingBP – Blood pressure level when the patient is at rest.
#Cholesterol – Cholesterol level in the patient’s blood.
#FastingBS – Whether fasting blood sugar is high (1 = Yes, 0 = No).
#RestingECG – Result of the resting electrocardiogram test.
#MaxHR – Maximum heart rate achieved during exercise.
#ExerciseAngina – Whether chest pain occurs during exercise (Y = Yes, N = No).
#Oldpeak – ST depression value measured during exercise (heart stress indicator).
#ST_Slope – Slope pattern of the ST segment during peak exercise.
#HeartDisease – Whether the patient has heart disease (1 = Yes, 0 = No).


#BASIC CHECKS
data.shape

data.head()

data.tail()

data.info()

data.dtypes

data.columns

num_cols = data.select_dtypes(include=['int64','float64'])
num_cols

cat_cols = data.select_dtypes(include=['object'])
cat_cols

data.describe()

# check for unique values
for x in cat_cols:
  print(x,'--->',data[x].unique())

  # check for value counts
for x in cat_cols:
  print(data[x].value_counts())



#DATA CLEANING
#CHECK FOR MISSING VALUES

data.isnull().sum()


#CHECK FOR DUPLICATES
data.duplicated().sum()


#EXPLORATORY DATA ANALYSIS
 #UNIVERATE

 # check trhe distribution of age with Heart Disease
plt.figure(figsize=(5,2))
sns.histplot(data,x='Age',kde=True)
plt.show()

# check the distribution RestingBP
plt.figure(figsize=(5,2))
sns.histplot(data,x='RestingBP',kde=True)
plt.show()

# check the distribution of Cholesterol
plt.figure(figsize=(5,2))
sns.histplot(data,x='Cholesterol',kde=True)
plt.show()

# check the distribution of Max HR
plt.figure(figsize=(5,2))
sns.histplot(data,x='MaxHR',kde=True)
plt.show()

# Count plot for Sex
plt.figure(figsize=(5,2))
sns.countplot(data,x='Sex',hue='HeartDisease')
plt.show()

# count plot for ChestPainType
plt.figure(figsize=(5,2))
sns.countplot(data,x='ChestPainType',hue='HeartDisease')
plt.show()





#TA (Typical Angina) – Chest pain caused by reduced blood flow to the heart, usually triggered by physical activity or stress.
#ATA (Atypical Angina) – Chest discomfort related to the heart but not showing all the typical angina symptoms.
#NAP (Non-Anginal Pain) – Chest pain not related to heart problems (may be due to muscle, gas, or other causes).
#ASY (Asymptomatic) – No chest pain symptoms even though a heart problem may still be present.



# count plot for RestingECG
plt.figure(figsize=(5,2))
sns.countplot(data,x='RestingECG',hue='HeartDisease')
plt.show()

# ExerciseAngina
plt.figure(figsize=(5,2))
sns.countplot(data,x='ExerciseAngina',hue='HeartDisease')
plt.show()

# ST_Slope
plt.figure(figsize=(5,2))
sns.countplot(data,x='ST_Slope',hue='HeartDisease')
plt.show()



#Up – Upsloping ST segment, generally considered normal during exercise.
#Flat– Flat ST segment, may indicate possible heart-related issues.
#Down – Downsloping ST segment, often associated with a higher risk of heart disease.


# check outliers Age , RestingBP	,Cholesterol,MaxHR,Oldpeak
plt.figure(figsize=(5,2))
sns.boxplot(data,x='Age')
plt.show()

plt.figure(figsize=(5,2))
sns.boxplot(data,x='RestingBP')
plt.show()


plt.figure(figsize=(5,2))
sns.boxplot(data,x='Cholesterol')
plt.show()

plt.figure(figsize=(5,2))
sns.boxplot(data,x='MaxHR')
plt.show()

plt.figure(figsize=(5,2))
sns.boxplot(data,x='Oldpeak')
plt.show()





#BIVARIATE ANALYSIS

# Age v/s RestingBP
plt.figure(figsize=(5,2))
sns.scatterplot(data,x='Age',y='RestingBP',hue='HeartDisease')
plt.show()

# Age v/s Cholesterol
plt.figure(figsize=(5,2))
sns.scatterplot(data,x='Age',y='Cholesterol',hue='HeartDisease')
plt.show()

# Age v/s MaxHR
plt.figure(figsize=(5,2))
sns.scatterplot(data,x='Age',y='MaxHR',hue='HeartDisease')
plt.show()

# age  v/s Oldpeak
plt.figure(figsize=(5,2))
sns.scatterplot(data,x='Age',y='Oldpeak',hue='HeartDisease')
plt.show()

# ChestPainType	 v/s cholesterol
plt.figure(figsize=(5,2))
sns.barplot(data,x='ChestPainType',y='Cholesterol')
plt.show()

# ChestPainType	 v/s RestingBP
plt.figure(figsize=(5,2))
sns.barplot(data,x='ChestPainType',y='RestingBP')
plt.show()

# ST_Slope v/s Cholesterol
plt.figure(figsize=(5,2))
sns.barplot(data,x='ST_Slope',y='Cholesterol')
plt.show()

# ST_Slope v/s RestingBP
plt.figure(figsize=(5,2))
sns.barplot(data,x='ST_Slope',y='RestingBP')
plt.show()



#PAIRPLOT

sns.pairplot(data,hue='HeartDisease')


#HEATMAP

# finding corr
num_cols.corr()

sns.heatmap(num_cols.corr(),annot=True)

data





#HANDLE OUTLIERS

# Age , RestingBP,Cholesterol,MaxHR,Oldpeak
fig,ax=plt.subplots(1,5,figsize=(7,2))
sns.boxplot(data,x='Age',ax=ax[0])
sns.boxplot(data,x='RestingBP',ax=ax[1])
sns.boxplot(data,x='Cholesterol',ax=ax[2])
sns.boxplot(data,x='MaxHR',ax=ax[3])
sns.boxplot(data,x='Oldpeak',ax=ax[4])
plt.tight_layout()


#Outliers are seen in RestingBP,Cholesterol,MaxHR,Oldpeak


# check the distribution
# Age , RestingBP,Cholesterol,MaxHR,Oldpeak
fig,ax=plt.subplots(1,4,figsize=(8,2))
sns.histplot(data,x='RestingBP',ax=ax[0])
sns.histplot(data,x='Cholesterol',ax=ax[1])
sns.histplot(data,x='MaxHR',ax=ax[2])
sns.histplot(data,x='Oldpeak',ax=ax[3])
plt.tight_layout()


df = ['RestingBP','Cholesterol','MaxHR','Oldpeak']
for x in df:
  print(x,'-->',data[x].skew())
  print()


  # RestingBP,MaxHR are normal
# Cholesterol , Oldpeak are skewed
# Out:
#      <input type="file" id="files-b9b801b8-f58e-4416-a4bd-f52d9b55135c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b9b801b8-f58e-4416-a4bd-f52d9b55135c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
